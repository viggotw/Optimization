# %%
import numpy as np
from sklearn.ensemble import GradientBoostingRegressor
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType
import pyomo.environ as pyo
from omlt import OmltBlock
from omlt.gbt import GBTBigMFormulation, GradientBoostedTreeModel
import matplotlib.pyplot as plt

# %%
# Train simple model
x = np.array(range(101)).reshape(-1,1)
y = np.array(range(101)).ravel()

model_gbt = GradientBoostingRegressor(n_estimators=5)
model_gbt.fit(x, y)
# Out:
# GradientBoostingRegressor(n_estimators=5)

# %%
# Get predictions directly from model
y_pred = model_gbt.predict(np.array(range(100)).reshape(-1,1))

# %%
# Get predictions from pyomo formulation
y_opt = []
for i in range(100):
    initial_type = [('float_input', FloatTensorType([None, 1]))]
    model_onx = convert_sklearn(model_gbt, initial_types=initial_type)

    m = pyo.ConcreteModel('Random GradientBoostingRegressor')

    m.gbt = OmltBlock()
    input_bounds = {0: (i, i)}  # Forces the input to equal the input from the previous prediction
    gbt_model = GradientBoostedTreeModel(
        model_onx,
        scaled_input_bounds=input_bounds,
    )

    formulation = GBTBigMFormulation(gbt_model)
    m.gbt.build_formulation(formulation)

    m.obj = pyo.Objective(expr=0)

    solver = pyo.SolverFactory('cbc')
    status = solver.solve(m, tee=False)

    # y_opt.append(m.gbt.outputs[0].value)
    y_opt.append(m.gbt.outputs[0].value + np.mean(y))
# Out:
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (1, 1).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (1, 1).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (2, 2).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (2, 2).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (3, 3).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (3, 3).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (4, 4).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (4, 4).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (5, 5).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (5, 5).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (6, 6).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (6, 6).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (7, 7).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (7, 7).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (8, 8).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (8, 8).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (9, 9).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (9, 9).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (10, 10).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (10, 10).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (11, 11).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (11, 11).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (12, 12).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (12, 12).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (13, 13).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (13, 13).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (14, 14).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (14, 14).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (15, 15).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (15, 15).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (16, 16).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (16, 16).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (17, 17).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (17, 17).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (18, 18).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (18, 18).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (19, 19).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (19, 19).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (20, 20).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (20, 20).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (21, 21).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (21, 21).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (22, 22).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (22, 22).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (23, 23).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (23, 23).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (24, 24).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (24, 24).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (25, 25).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (25, 25).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (26, 26).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (26, 26).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (27, 27).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (27, 27).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (28, 28).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (28, 28).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (29, 29).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (29, 29).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (30, 30).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (30, 30).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (31, 31).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (31, 31).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (32, 32).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (32, 32).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (33, 33).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (33, 33).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (34, 34).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (34, 34).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (35, 35).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (35, 35).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (36, 36).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (36, 36).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (37, 37).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (37, 37).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (38, 38).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (38, 38).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (39, 39).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (39, 39).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (40, 40).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (40, 40).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (41, 41).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (41, 41).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (42, 42).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (42, 42).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (43, 43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (43, 43).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (44, 44).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (44, 44).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (45, 45).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (45, 45).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (46, 46).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (46, 46).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (47, 47).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (47, 47).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (48, 48).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (48, 48).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (49, 49).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (49, 49).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (50, 50).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (50, 50).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (51, 51).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (51, 51).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (52, 52).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (52, 52).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (53, 53).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (53, 53).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (54, 54).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (54, 54).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (55, 55).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (55, 55).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (56, 56).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (56, 56).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (57, 57).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (57, 57).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (58, 58).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (58, 58).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (59, 59).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (59, 59).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (60, 60).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (60, 60).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (61, 61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (61, 61).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (62, 62).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (62, 62).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (63, 63).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (63, 63).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (64, 64).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (64, 64).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (65, 65).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (65, 65).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (66, 66).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (66, 66).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (67, 67).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (67, 67).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (68, 68).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (68, 68).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (69, 69).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (69, 69).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (70, 70).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (70, 70).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (71, 71).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (71, 71).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (72, 72).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (72, 72).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (73, 73).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (73, 73).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (74, 74).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (74, 74).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (75, 75).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (75, 75).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (76, 76).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (76, 76).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (77, 77).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (77, 77).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (78, 78).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (78, 78).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (79, 79).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (79, 79).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (80, 80).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (80, 80).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (81, 81).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (81, 81).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (82, 82).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (82, 82).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (83, 83).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (83, 83).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (84, 84).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (84, 84).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (85, 85).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (85, 85).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (86, 86).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (86, 86).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (87, 87).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (87, 87).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (88, 88).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (88, 88).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (89, 89).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (89, 89).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (90, 90).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (90, 90).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (91, 91).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (91, 91).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (92, 92).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (92, 92).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (93, 93).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (93, 93).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (94, 94).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (94, 94).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (95, 95).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (95, 95).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (96, 96).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (96, 96).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (97, 97).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (97, 97).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (98, 98).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (98, 98).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (99, 99).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING (W1002): Setting Var 'gbt.scaled_inputs[0]' to a numeric value `0`
#     outside the bounds (99, 99).
#     See also https://pyomo.readthedocs.io/en/stable/errors.html#w1002
# WARNING: Constant objective detected, replacing with a placeholder to prevent
#     solver failure.

# %%
plt.plot(y_pred)
plt.plot(y_opt, '--')
plt.title('Predictions')
plt.legend(['Original model', 'Pyomo formulation'])
